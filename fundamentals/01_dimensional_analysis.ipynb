# %% [markdown]
# # Physical question

# %% [markdown]
# ## Variables and units

# %% [markdown]
# ## Order-of-magnitude estimate

# %% [markdown]
# ## Derivation

# %% [markdown]
# ## Prediction before coding

# %% [markdown]
# ## Python simulation

# %% [markdown]
# ## Limiting cases

# %% [markdown]
# ## Experimental connection

# %% [markdown]
# ## What surprised me?

# %% [markdown]
# ## Victor questions
